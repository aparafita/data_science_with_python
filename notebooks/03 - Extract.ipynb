# %% [markdown]
# # Extract

# %%
# Make the project root folder accessible
from domino.utils.jupyter import notebook_init
notebook_init()

# %%
import os
import os.path
import time
import json

from selenium.webdriver import Firefox, FirefoxProfile
from selenium.common.exceptions import StaleElementReferenceException

# %%
# First, setup the browser profile with which we will work
profile = FirefoxProfile()

profile.set_preference('browser.download.folderList', 2)
profile.set_preference('browser.download.manager.showWhenStarting', False)
profile.set_preference('browser.download.dir', os.path.join(os.getcwd(), 'data'))
profile.set_preference('browser.helperApps.neverAsk.saveToDisk', 'text/csv/xls')

ff = Firefox(profile) # this opens a browser (Firefox) window

# %%
# Define the url from where to extract data
url = 'https://www.whoscored.com/Regions/206/Tournaments/4/Seasons/5933/Stages/12647/PlayerStatistics/Spain-La-Liga-2015-2016'

# %%
ff.get(url) # open the url

# %%
# Extract the column names of the table
header = [
    (th.get_attribute('class'), th.text)
    
    for th in ff.find_elements_by_xpath(
        "//thead[@id='player-table-statistics-head']//th"
    )
]

# %%
header
# Out:
# [('rank', 'R'),
#  ('rgn', ''),
#  ('pn', 'Player'),
#  ('global sortable ap   ', 'Apps'),
#  ('global sortable minsPlayed   ', 'Mins'),
#  ('global sortable goal   ', 'Goals'),
#  ('global sortable assistTotal   ', 'Assists'),
#  ('global sortable yellowCard   ', 'Yel'),
#  ('global sortable redCard   ', 'Red'),
#  ('global sortable shotsPerGame   ', 'SpG'),
#  ('global sortable passSuccess   ', 'PS%'),
#  ('global sortable aerialWonPerGame   ', 'AerialsWon'),
#  ('global sortable manOfTheMatch   ', 'MotM'),
#  ('global sortable rating', 'Rating')]

# %%
# Clean its names

header = [
    (k.replace('global', '').replace('sortable', '').strip(), v)
    for k, v in header
]

# %%
header
# Out:
# [('rank', 'R'),
#  ('rgn', ''),
#  ('pn', 'Player'),
#  ('ap', 'Apps'),
#  ('minsPlayed', 'Mins'),
#  ('goal', 'Goals'),
#  ('assistTotal', 'Assists'),
#  ('yellowCard', 'Yel'),
#  ('redCard', 'Red'),
#  ('shotsPerGame', 'SpG'),
#  ('passSuccess', 'PS%'),
#  ('aerialWonPerGame', 'AerialsWon'),
#  ('manOfTheMatch', 'MotM'),
#  ('rating', 'Rating')]

# %%
# Select all players
ff.find_element_by_xpath('//div[@class="statistics-table-filter"]//dl[@id="apps"]//dd[2]/a').click()
time.sleep(3) # wait for some time to avoid problems with page loading

# %%
rows = []

while True:
    subrows = []
    
    try:
        for tr in ff.find_elements_by_xpath(
            "//tbody[@id='player-table-statistics-body']//tr"
        ):
            d = {}

            for (th, th_title), td in zip(
                header,
                tr.find_elements_by_xpath(".//td")
            ):
                if th == 'rgn':
                    d[th] = td.find_element_by_xpath('./span').get_attribute('class')
                elif th == 'pn':
                    player = td.find_element_by_xpath(
                        './/a[@class="player-link"]'
                    )

                    d['%s %s' % (th, 'player_url')] = player.get_attribute('href')
                    d['%s %s' % (th, 'player_name')] = player.text

                    team = td.find_element_by_xpath(
                        './/a[@class="player-meta-data"]'
                    )

                    d['%s %s' % (th, 'team_url')] = team.get_attribute('href')
                    d['%s %s' % (th, 'team_name')] = team.find_element_by_xpath(
                        './/span'
                    ).text

                    d['%s %s' % (th, 'player_metadata')] = ''.join(
                        element.text
                        for element in td.find_elements_by_xpath(
                            './/span[@class="player-meta-data"]'
                        )
                    )
                else:
                    d[th] = td.text                

            subrows.append(d)
            
    except StaleElementReferenceException: # the loading time was slower than expected
        continue # repeat all rows again
        
    # everything worked, so add all loaded rows to rows
    rows += subrows

    # Click the next button
    button = ff.find_element_by_xpath('//a[@id="next"]')
    if 'disabled' in button.get_attribute('class'):
        break
    else:
        button.click()
        time.sleep(1)

# %%
rows
# Out:
# [{'aerialWonPerGame': '0.2',
#   'ap': '31(2)',
#   'assistTotal': '16',
#   'goal': '26',
#   'manOfTheMatch': '13',
#   'minsPlayed': '2730',
#   'passSuccess': '81.9',
#   'pn player_metadata': '29, AM(CR),FW',
#   'pn player_name': 'Lionel Messi',
#   'pn player_url': 'https://www.whoscored.com/Players/11119',
#   'pn team_name': 'Barcelona,',
#   'pn team_url': 'https://www.whoscored.com/Teams/65',
#   'rank': '1',
#   'rating': '8.46',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-ar',
#   'shotsPerGame': '4.8',
#   'yellowCard': '3'},
#  {'aerialWonPerGame': '0.6',
#   'ap': '34',
#   'assistTotal': '12',
#   'goal': '24',
#   'manOfTheMatch': '7',
#   'minsPlayed': '3057',
#   'passSuccess': '80.9',
#   'pn player_metadata': '24, AM(CLR),FW',
#   'pn player_name': 'Neymar',
#   'pn player_url': 'https://www.whoscored.com/Players/50835',
#   'pn team_name': 'Barcelona,',
#   'pn team_url': 'https://www.whoscored.com/Teams/65',
#   'rank': '2',
#   'rating': '8.43',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-br',
#   'shotsPerGame': '3.6',
#   'yellowCard': '6'},
#  {'aerialWonPerGame': '0.9',
#   'ap': '21(2)',
#   'assistTotal': '10',
#   'goal': '19',
#   'manOfTheMatch': '5',
#   'minsPlayed': '1741',
#   'passSuccess': '79.9',
#   'pn player_metadata': '27, M(CLR),FW',
#   'pn player_name': 'Gareth Bale',
#   'pn player_url': 'https://www.whoscored.com/Players/13812',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '3',
#   'rating': '8.12',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-gb-wls',
#   'shotsPerGame': '3.5',
#   'yellowCard': '2'},
#  {'aerialWonPerGame': '0.4',
#   'ap': '35',
#   'assistTotal': '16',
#   'goal': '40',
#   'manOfTheMatch': '8',
#   'minsPlayed': '3150',
#   'passSuccess': '73.1',
#   'pn player_metadata': '29, AM(CLR),FW',
#   'pn player_name': 'Luis Suárez',
#   'pn player_url': 'https://www.whoscored.com/Players/22221',
#   'pn team_name': 'Barcelona,',
#   'pn team_url': 'https://www.whoscored.com/Teams/65',
#   'rank': '4',
#   'rating': '8.01',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-uy',
#   'shotsPerGame': '3.9',
#   'yellowCard': '6'},
#  {'aerialWonPerGame': '1.6',
#   'ap': '36',
#   'assistTotal': '11',
#   'goal': '35',
#   'manOfTheMatch': '8',
#   'minsPlayed': '3185',
#   'passSuccess': '79.4',
#   'pn player_metadata': '31, M(L),FW',
#   'pn player_name': 'Cristiano Ronaldo',
#   'pn player_url': 'https://www.whoscored.com/Players/5583',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '5',
#   'rating': '7.99',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-pt',
#   'shotsPerGame': '6.3',
#   'yellowCard': '3'},
#  {'aerialWonPerGame': '0.4',
#   'ap': '26(1)',
#   'assistTotal': '7',
#   'goal': '24',
#   'manOfTheMatch': '3',
#   'minsPlayed': '1994',
#   'passSuccess': '81.5',
#   'pn player_metadata': '28, FW',
#   'pn player_name': 'Karim Benzema',
#   'pn player_url': 'https://www.whoscored.com/Players/14296',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '6',
#   'rating': '7.65',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-fr',
#   'shotsPerGame': '3.6',
#   'yellowCard': '1'},
#  {'aerialWonPerGame': '1.3',
#   'ap': '32',
#   'assistTotal': '4',
#   'goal': '1',
#   'manOfTheMatch': '3',
#   'minsPlayed': '2834',
#   'passSuccess': '82.5',
#   'pn player_metadata': '31, D(L)',
#   'pn player_name': 'Filipe Luis',
#   'pn player_url': 'https://www.whoscored.com/Players/22152',
#   'pn team_name': 'Atletico Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/63',
#   'rank': '7',
#   'rating': '7.60',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-br',
#   'shotsPerGame': '0.3',
#   'yellowCard': '11'},
#  {'aerialWonPerGame': '3',
#   'ap': '31',
#   'assistTotal': '1',
#   'goal': '1',
#   'manOfTheMatch': '6',
#   'minsPlayed': '2651',
#   'passSuccess': '78.4',
#   'pn player_metadata': '30, D(C)',
#   'pn player_name': 'Diego Godín',
#   'pn player_url': 'https://www.whoscored.com/Players/26059',
#   'pn team_name': 'Atletico Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/63',
#   'rank': '8',
#   'rating': '7.52',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-uy',
#   'shotsPerGame': '0.8',
#   'yellowCard': '5'},
#  {'aerialWonPerGame': '1.5',
#   'ap': '36(2)',
#   'assistTotal': '5',
#   'goal': '22',
#   'manOfTheMatch': '8',
#   'minsPlayed': '3058',
#   'passSuccess': '78.3',
#   'pn player_metadata': '25, AM(CLR),FW',
#   'pn player_name': 'Antoine Griezmann',
#   'pn player_url': 'https://www.whoscored.com/Players/80241',
#   'pn team_name': 'Atletico Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/63',
#   'rank': '9',
#   'rating': '7.50',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-fr',
#   'shotsPerGame': '2.4',
#   'yellowCard': '5'},
#  {'aerialWonPerGame': '0.7',
#   'ap': '34(1)',
#   'assistTotal': '14',
#   'goal': '5',
#   'manOfTheMatch': '2',
#   'minsPlayed': '2973',
#   'passSuccess': '82',
#   'pn player_metadata': '24, M(CLR)',
#   'pn player_name': 'Koke',
#   'pn player_url': 'https://www.whoscored.com/Players/80764',
#   'pn team_name': 'Atletico Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/63',
#   'rank': '10',
#   'rating': '7.49',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '1.2',
#   'yellowCard': '4'},
#  {'aerialWonPerGame': '0.6',
#   'ap': '27(2)',
#   'assistTotal': '7',
#   'goal': '12',
#   'manOfTheMatch': '9',
#   'minsPlayed': '2473',
#   'passSuccess': '67.6',
#   'pn player_metadata': '29, AM(L)',
#   'pn player_name': 'Nolito',
#   'pn player_url': 'https://www.whoscored.com/Players/91267',
#   'pn team_name': 'Celta Vigo,',
#   'pn team_url': 'https://www.whoscored.com/Teams/62',
#   'rank': '11',
#   'rating': '7.44',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '2.8',
#   'yellowCard': '9'},
#  {'aerialWonPerGame': '0.2',
#   'ap': '28(2)',
#   'assistTotal': '3',
#   'goal': '2',
#   'manOfTheMatch': '2',
#   'minsPlayed': '2474',
#   'passSuccess': '84.3',
#   'pn player_metadata': '28, D(L)',
#   'pn player_name': 'Marcelo',
#   'pn player_url': 'https://www.whoscored.com/Players/20241',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '12',
#   'rating': '7.44',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-br',
#   'shotsPerGame': '0.6',
#   'yellowCard': '2'},
#  {'aerialWonPerGame': '2.6',
#   'ap': '26(5)',
#   'assistTotal': '2',
#   'goal': '4',
#   'manOfTheMatch': '3',
#   'minsPlayed': '2329',
#   'passSuccess': '76.3',
#   'pn player_metadata': '21, D(C),M(CLR)',
#   'pn player_name': 'Saúl Ñíguez',
#   'pn player_url': 'https://www.whoscored.com/Players/112161',
#   'pn team_name': 'Atletico Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/63',
#   'rank': '13',
#   'rating': '7.37',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '1.5',
#   'yellowCard': '1'},
#  {'aerialWonPerGame': '0.3',
#   'ap': '31(1)',
#   'assistTotal': '4',
#   'goal': '2',
#   'manOfTheMatch': '6',
#   'minsPlayed': '2629',
#   'passSuccess': '90.9',
#   'pn player_metadata': '30, M(C)',
#   'pn player_name': 'Luka Modric',
#   'pn player_url': 'https://www.whoscored.com/Players/20874',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '14',
#   'rating': '7.37',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-hr',
#   'shotsPerGame': '1.1',
#   'yellowCard': '5'},
#  {'aerialWonPerGame': '4.8',
#   'ap': '30(4)',
#   'assistTotal': '6',
#   'goal': '20',
#   'manOfTheMatch': '6',
#   'minsPlayed': '2776',
#   'passSuccess': '60.6',
#   'pn player_metadata': '35, FW',
#   'pn player_name': 'Aduriz',
#   'pn player_url': 'https://www.whoscored.com/Players/9294',
#   'pn team_name': 'Athletic Club,',
#   'pn team_url': 'https://www.whoscored.com/Teams/53',
#   'rank': '15',
#   'rating': '7.37',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '2.7',
#   'yellowCard': '9'},
#  {'aerialWonPerGame': '0.3',
#   'ap': '32',
#   'assistTotal': '10',
#   'goal': '1',
#   'manOfTheMatch': '-',
#   'minsPlayed': '2745',
#   'passSuccess': '93.9',
#   'pn player_metadata': '26, M(C)',
#   'pn player_name': 'Toni Kroos',
#   'pn player_url': 'https://www.whoscored.com/Players/31772',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '16',
#   'rating': '7.33',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-de',
#   'shotsPerGame': '0.6',
#   'yellowCard': '3'},
#  {'aerialWonPerGame': '3',
#   'ap': '30',
#   'assistTotal': '-',
#   'goal': '2',
#   'manOfTheMatch': '4',
#   'minsPlayed': '2682',
#   'passSuccess': '81.3',
#   'pn player_metadata': '24, D(CR)',
#   'pn player_name': 'Shkodran Mustafi',
#   'pn player_url': 'https://www.whoscored.com/Players/80921',
#   'pn team_name': 'Valencia,',
#   'pn team_url': 'https://www.whoscored.com/Teams/55',
#   'rank': '17',
#   'rating': '7.33',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-de',
#   'shotsPerGame': '0.7',
#   'yellowCard': '14'},
#  {'aerialWonPerGame': '0.2',
#   'ap': '17(9)',
#   'assistTotal': '8',
#   'goal': '7',
#   'manOfTheMatch': '2',
#   'minsPlayed': '1518',
#   'passSuccess': '86.9',
#   'pn player_metadata': '25, AM(CLR)',
#   'pn player_name': 'James Rodríguez',
#   'pn player_url': 'https://www.whoscored.com/Players/71182',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '18',
#   'rating': '7.32',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-co',
#   'shotsPerGame': '1.5',
#   'yellowCard': '1'},
#  {'aerialWonPerGame': '1.9',
#   'ap': '17(6)',
#   'assistTotal': '3',
#   'goal': '1',
#   'manOfTheMatch': '1',
#   'minsPlayed': '1526',
#   'passSuccess': '87.2',
#   'pn player_metadata': '24, DMC',
#   'pn player_name': 'Casemiro',
#   'pn player_url': 'https://www.whoscored.com/Players/88526',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '19',
#   'rating': '7.30',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-br',
#   'shotsPerGame': '0.9',
#   'yellowCard': '7'},
#  {'aerialWonPerGame': '1.7',
#   'ap': '34(1)',
#   'assistTotal': '4',
#   'goal': '-',
#   'manOfTheMatch': '1',
#   'minsPlayed': '2906',
#   'passSuccess': '89.8',
#   'pn player_metadata': '28, DMC',
#   'pn player_name': 'Sergio Busquets',
#   'pn player_url': 'https://www.whoscored.com/Players/44721',
#   'pn team_name': 'Barcelona,',
#   'pn team_url': 'https://www.whoscored.com/Teams/65',
#   'rank': '20',
#   'rating': '7.28',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.2',
#   'yellowCard': '6'},
#  {'aerialWonPerGame': '1.3',
#   'ap': '23(1)',
#   'assistTotal': '5',
#   'goal': '2',
#   'manOfTheMatch': '-',
#   'minsPlayed': '2044',
#   'passSuccess': '86',
#   'pn player_metadata': '25, D(R)',
#   'pn player_name': 'Danilo',
#   'pn player_url': 'https://www.whoscored.com/Players/88300',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '21',
#   'rating': '7.27',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-br',
#   'shotsPerGame': '0.8',
#   'yellowCard': '6'},
#  {'aerialWonPerGame': '1.8',
#   'ap': '32(1)',
#   'assistTotal': '1',
#   'goal': '1',
#   'manOfTheMatch': '2',
#   'minsPlayed': '2847',
#   'passSuccess': '81',
#   'pn player_metadata': '26, M(C)',
#   'pn player_name': 'Asier Illarramendi',
#   'pn player_url': 'https://www.whoscored.com/Players/87094',
#   'pn team_name': 'Real Sociedad,',
#   'pn team_url': 'https://www.whoscored.com/Teams/68',
#   'rank': '22',
#   'rating': '7.27',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.7',
#   'yellowCard': '15'},
#  {'aerialWonPerGame': '2.7',
#   'ap': '21',
#   'assistTotal': '1',
#   'goal': '1',
#   'manOfTheMatch': '-',
#   'minsPlayed': '1887',
#   'passSuccess': '87.6',
#   'pn player_metadata': '33, D(C)',
#   'pn player_name': 'Pepe',
#   'pn player_url': 'https://www.whoscored.com/Players/10105',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '23',
#   'rating': '7.27',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-pt',
#   'shotsPerGame': '0.6',
#   'yellowCard': '5'},
#  {'aerialWonPerGame': '3.7',
#   'ap': '27(3)',
#   'assistTotal': '6',
#   'goal': '7',
#   'manOfTheMatch': '2',
#   'minsPlayed': '2375',
#   'passSuccess': '63.7',
#   'pn player_metadata': '30, M(CLR),FW',
#   'pn player_name': 'Raúl García',
#   'pn player_url': 'https://www.whoscored.com/Players/11386',
#   'pn team_name': 'Athletic Club,',
#   'pn team_url': 'https://www.whoscored.com/Teams/53',
#   'rank': '24',
#   'rating': '7.25',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '2.6',
#   'yellowCard': '10'},
#  {'aerialWonPerGame': '2.8',
#   'ap': '26(1)',
#   'assistTotal': '-',
#   'goal': '2',
#   'manOfTheMatch': '2',
#   'minsPlayed': '2313',
#   'passSuccess': '81.7',
#   'pn player_metadata': '23, D(C),DMC',
#   'pn player_name': 'Diego Reyes',
#   'pn player_url': 'https://www.whoscored.com/Players/86235',
#   'pn team_name': 'Real Sociedad,',
#   'pn team_url': 'https://www.whoscored.com/Teams/68',
#   'rank': '25',
#   'rating': '7.24',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-mx',
#   'shotsPerGame': '0.4',
#   'yellowCard': '3'},
#  {'aerialWonPerGame': '0.4',
#   'ap': '25(3)',
#   'assistTotal': '2',
#   'goal': '1',
#   'manOfTheMatch': '1',
#   'minsPlayed': '2248',
#   'passSuccess': '88.3',
#   'pn player_metadata': '32, M(CL)',
#   'pn player_name': 'Andrés Iniesta',
#   'pn player_url': 'https://www.whoscored.com/Players/9486',
#   'pn team_name': 'Barcelona,',
#   'pn team_url': 'https://www.whoscored.com/Teams/65',
#   'rank': '26',
#   'rating': '7.24',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.8',
#   'yellowCard': '2'},
#  {'aerialWonPerGame': '2.9',
#   'ap': '25(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '3',
#   'minsPlayed': '2271',
#   'passSuccess': '84.3',
#   'pn player_metadata': '26, DMC',
#   'pn player_name': 'Grzegorz Krychowiak',
#   'pn player_url': 'https://www.whoscored.com/Players/67424',
#   'pn team_name': 'Sevilla,',
#   'pn team_url': 'https://www.whoscored.com/Teams/67',
#   'rank': '27',
#   'rating': '7.23',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-pl',
#   'shotsPerGame': '0.8',
#   'yellowCard': '6'},
#  {'aerialWonPerGame': '1',
#   'ap': '19(3)',
#   'assistTotal': '4',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '1638',
#   'passSuccess': '88',
#   'pn player_metadata': '24, D(R)',
#   'pn player_name': 'Daniel Carvajal',
#   'pn player_url': 'https://www.whoscored.com/Players/106883',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '28',
#   'rating': '7.22',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.4',
#   'yellowCard': '6'},
#  {'aerialWonPerGame': '2.7',
#   'ap': '21',
#   'assistTotal': '4',
#   'goal': '-',
#   'manOfTheMatch': '2',
#   'minsPlayed': '1849',
#   'passSuccess': '76.5',
#   'pn player_metadata': '26, D(L)',
#   'pn player_name': 'Yuri',
#   'pn player_url': 'https://www.whoscored.com/Players/56057',
#   'pn team_name': 'Real Sociedad,',
#   'pn team_url': 'https://www.whoscored.com/Teams/68',
#   'rank': '29',
#   'rating': '7.22',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.7',
#   'yellowCard': '10'},
#  {'aerialWonPerGame': '1.3',
#   'ap': '34(1)',
#   'assistTotal': '3',
#   'goal': '1',
#   'manOfTheMatch': '2',
#   'minsPlayed': '2883',
#   'passSuccess': '82.1',
#   'pn player_metadata': '33, M(C)',
#   'pn player_name': 'Gabi',
#   'pn player_url': 'https://www.whoscored.com/Players/10053',
#   'pn team_name': 'Atletico Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/63',
#   'rank': '30',
#   'rating': '7.22',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.5',
#   'yellowCard': '11'},
#  {'aerialWonPerGame': '2.1',
#   'ap': '27',
#   'assistTotal': '1',
#   'goal': '1',
#   'manOfTheMatch': '1',
#   'minsPlayed': '2430',
#   'passSuccess': '73.3',
#   'pn player_metadata': '21, D(C)',
#   'pn player_name': 'Giménez',
#   'pn player_url': 'https://www.whoscored.com/Players/135914',
#   'pn team_name': 'Atletico Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/63',
#   'rank': '31',
#   'rating': '7.22',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-uy',
#   'shotsPerGame': '0.4',
#   'yellowCard': '8'},
#  {'aerialWonPerGame': '3.2',
#   'ap': '23',
#   'assistTotal': '1',
#   'goal': '2',
#   'manOfTheMatch': '3',
#   'minsPlayed': '2008',
#   'passSuccess': '73.5',
#   'pn player_metadata': '26, M(C)',
#   'pn player_name': 'Ignacio Camacho',
#   'pn player_url': 'https://www.whoscored.com/Players/35199',
#   'pn team_name': 'Malaga,',
#   'pn team_url': 'https://www.whoscored.com/Teams/69',
#   'rank': '32',
#   'rating': '7.22',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '1',
#   'yellowCard': '7'},
#  {'aerialWonPerGame': '0.2',
#   'ap': '20(5)',
#   'assistTotal': '2',
#   'goal': '5',
#   'manOfTheMatch': '4',
#   'minsPlayed': '1726',
#   'passSuccess': '82.9',
#   'pn player_metadata': '28, M(C)',
#   'pn player_name': 'Éver Banega',
#   'pn player_url': 'https://www.whoscored.com/Players/33724',
#   'pn team_name': 'Sevilla,',
#   'pn team_url': 'https://www.whoscored.com/Teams/67',
#   'rank': '33',
#   'rating': '7.21',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-ar',
#   'shotsPerGame': '1.6',
#   'yellowCard': '6'},
#  {'aerialWonPerGame': '0.2',
#   'ap': '10(15)',
#   'assistTotal': '6',
#   'goal': '4',
#   'manOfTheMatch': '1',
#   'minsPlayed': '1231',
#   'passSuccess': '85.8',
#   'pn player_metadata': '25, AM(R)',
#   'pn player_name': 'Lucas Vázquez',
#   'pn player_url': 'https://www.whoscored.com/Players/144511',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '34',
#   'rating': '7.21',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.9',
#   'yellowCard': '4'},
#  {'aerialWonPerGame': '1.6',
#   'ap': '26(1)',
#   'assistTotal': '-',
#   'goal': '3',
#   'manOfTheMatch': '2',
#   'minsPlayed': '2353',
#   'passSuccess': '84.5',
#   'pn player_metadata': '26, D(CL)',
#   'pn player_name': 'Pedro Bigas',
#   'pn player_url': 'https://www.whoscored.com/Players/108100',
#   'pn team_name': 'Las Palmas,',
#   'pn team_url': 'https://www.whoscored.com/Teams/838',
#   'rank': '35',
#   'rating': '7.20',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.6',
#   'yellowCard': '5'},
#  {'aerialWonPerGame': '0.4',
#   'ap': '36',
#   'assistTotal': '9',
#   'goal': '10',
#   'manOfTheMatch': '5',
#   'minsPlayed': '3121',
#   'passSuccess': '81.9',
#   'pn player_metadata': '26, AM(CL),FW',
#   'pn player_name': 'Jonathan Viera',
#   'pn player_url': 'https://www.whoscored.com/Players/91304',
#   'pn team_name': 'Las Palmas,',
#   'pn team_url': 'https://www.whoscored.com/Teams/838',
#   'rank': '36',
#   'rating': '7.19',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '2.4',
#   'yellowCard': '4'},
#  {'aerialWonPerGame': '3',
#   'ap': '30',
#   'assistTotal': '2',
#   'goal': '-',
#   'manOfTheMatch': '2',
#   'minsPlayed': '2608',
#   'passSuccess': '71.7',
#   'pn player_metadata': '36, D(C)',
#   'pn player_name': 'Weligton',
#   'pn player_url': 'https://www.whoscored.com/Players/13289',
#   'pn team_name': 'Malaga,',
#   'pn team_url': 'https://www.whoscored.com/Teams/69',
#   'rank': '37',
#   'rating': '7.18',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-br',
#   'shotsPerGame': '0.1',
#   'yellowCard': '5'},
#  {'aerialWonPerGame': '1.1',
#   'ap': '15',
#   'assistTotal': '1',
#   'goal': '1',
#   'manOfTheMatch': '-',
#   'minsPlayed': '1338',
#   'passSuccess': '90.3',
#   'pn player_metadata': '30, M(CR)',
#   'pn player_name': 'Augusto Fernández',
#   'pn player_url': 'https://www.whoscored.com/Players/25956',
#   'pn team_name': 'Celta Vigo,',
#   'pn team_url': 'https://www.whoscored.com/Teams/62',
#   'rank': '38',
#   'rating': '7.17',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-ar',
#   'shotsPerGame': '0.6',
#   'yellowCard': '7'},
#  {'aerialWonPerGame': '0.9',
#   'ap': '30(6)',
#   'assistTotal': '2',
#   'goal': '7',
#   'manOfTheMatch': '2',
#   'minsPlayed': '2581',
#   'passSuccess': '88.1',
#   'pn player_metadata': '28, M(C)',
#   'pn player_name': 'Ivan Rakitic',
#   'pn player_url': 'https://www.whoscored.com/Players/22732',
#   'pn team_name': 'Barcelona,',
#   'pn team_url': 'https://www.whoscored.com/Teams/65',
#   'rank': '39',
#   'rating': '7.17',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-hr',
#   'shotsPerGame': '1.3',
#   'yellowCard': '3'},
#  {'aerialWonPerGame': '2.8',
#   'ap': '6',
#   'assistTotal': '-',
#   'goal': '1',
#   'manOfTheMatch': '1',
#   'minsPlayed': '540',
#   'passSuccess': '72.9',
#   'pn player_metadata': '34, D(C)',
#   'pn player_name': 'Antolin Alcaraz',
#   'pn player_url': 'https://www.whoscored.com/Players/9474',
#   'pn team_name': 'Las Palmas,',
#   'pn team_url': 'https://www.whoscored.com/Teams/838',
#   'rank': '40',
#   'rating': '7.16',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-py',
#   'shotsPerGame': '0.3',
#   'yellowCard': '2'},
#  {'aerialWonPerGame': '0.8',
#   'ap': '30(3)',
#   'assistTotal': '5',
#   'goal': '8',
#   'manOfTheMatch': '3',
#   'minsPlayed': '2735',
#   'passSuccess': '85.5',
#   'pn player_metadata': '27, M(C)',
#   'pn player_name': 'Daniel Parejo',
#   'pn player_url': 'https://www.whoscored.com/Players/28186',
#   'pn team_name': 'Valencia,',
#   'pn team_url': 'https://www.whoscored.com/Teams/55',
#   'rank': '41',
#   'rating': '7.15',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '1.4',
#   'yellowCard': '8'},
#  {'aerialWonPerGame': '1.7',
#   'ap': '23',
#   'assistTotal': '2',
#   'goal': '2',
#   'manOfTheMatch': '-',
#   'minsPlayed': '1946',
#   'passSuccess': '90.3',
#   'pn player_metadata': '30, D(CR)',
#   'pn player_name': 'Sergio Ramos',
#   'pn player_url': 'https://www.whoscored.com/Players/9909',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '42',
#   'rating': '7.15',
#   'redCard': '2',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.8',
#   'yellowCard': '7'},
#  {'aerialWonPerGame': '1.4',
#   'ap': '12(2)',
#   'assistTotal': '2',
#   'goal': '1',
#   'manOfTheMatch': '-',
#   'minsPlayed': '1053',
#   'passSuccess': '84.7',
#   'pn player_metadata': '35, M(C)',
#   'pn player_name': 'Tiago',
#   'pn player_url': 'https://www.whoscored.com/Players/8128',
#   'pn team_name': 'Atletico Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/63',
#   'rank': '43',
#   'rating': '7.14',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-pt',
#   'shotsPerGame': '0.5',
#   'yellowCard': '4'},
#  {'aerialWonPerGame': '2',
#   'ap': '30',
#   'assistTotal': '1',
#   'goal': '2',
#   'manOfTheMatch': '1',
#   'minsPlayed': '2592',
#   'passSuccess': '90.5',
#   'pn player_metadata': '29, D(C)',
#   'pn player_name': 'Gerard Piqué',
#   'pn player_url': 'https://www.whoscored.com/Players/12712',
#   'pn team_name': 'Barcelona,',
#   'pn team_url': 'https://www.whoscored.com/Teams/65',
#   'rank': '44',
#   'rating': '7.14',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.4',
#   'yellowCard': '12'},
#  {'aerialWonPerGame': '1.8',
#   'ap': '28(3)',
#   'assistTotal': '1',
#   'goal': '5',
#   'manOfTheMatch': '5',
#   'minsPlayed': '2594',
#   'passSuccess': '86.4',
#   'pn player_metadata': '32, M(C)',
#   'pn player_name': 'Bruno',
#   'pn player_url': 'https://www.whoscored.com/Players/14231',
#   'pn team_name': 'Villarreal,',
#   'pn team_url': 'https://www.whoscored.com/Teams/839',
#   'rank': '45',
#   'rating': '7.14',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.8',
#   'yellowCard': '5'},
#  {'aerialWonPerGame': '0.7',
#   'ap': '10(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '925',
#   'passSuccess': '75.6',
#   'pn player_metadata': '19, D(L)',
#   'pn player_name': 'Adrián Marín',
#   'pn player_url': 'https://www.whoscored.com/Players/243271',
#   'pn team_name': 'Villarreal,',
#   'pn team_url': 'https://www.whoscored.com/Teams/839',
#   'rank': '46',
#   'rating': '7.14',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.1',
#   'yellowCard': '1'},
#  {'aerialWonPerGame': '2.6',
#   'ap': '7(1)',
#   'assistTotal': '1',
#   'goal': '1',
#   'manOfTheMatch': '1',
#   'minsPlayed': '641',
#   'passSuccess': '63.4',
#   'pn player_metadata': '21, D(L)',
#   'pn player_name': 'Federico Ricca',
#   'pn player_url': 'https://www.whoscored.com/Players/303080',
#   'pn team_name': 'Malaga,',
#   'pn team_url': 'https://www.whoscored.com/Teams/69',
#   'rank': '47',
#   'rating': '7.14',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-uy',
#   'shotsPerGame': '0.3',
#   'yellowCard': '3'},
#  {'aerialWonPerGame': '1.9',
#   'ap': '14(2)',
#   'assistTotal': '3',
#   'goal': '1',
#   'manOfTheMatch': '-',
#   'minsPlayed': '1130',
#   'passSuccess': '78.5',
#   'pn player_metadata': '30, M(CL)',
#   'pn player_name': 'David Zurutuza',
#   'pn player_url': 'https://www.whoscored.com/Players/31096',
#   'pn team_name': 'Real Sociedad,',
#   'pn team_url': 'https://www.whoscored.com/Teams/68',
#   'rank': '48',
#   'rating': '7.13',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '1.1',
#   'yellowCard': '1'},
#  {'aerialWonPerGame': '0.4',
#   'ap': '34',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '1',
#   'minsPlayed': '3060',
#   'passSuccess': '63.4',
#   'pn player_metadata': '29, GK',
#   'pn player_name': 'Keylor Navas',
#   'pn player_url': 'https://www.whoscored.com/Players/65901',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '49',
#   'rating': '7.12',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-cr',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '0.4',
#   'ap': '17',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '1',
#   'minsPlayed': '1530',
#   'passSuccess': '52.4',
#   'pn player_metadata': '25, GK',
#   'pn player_name': 'Jaume',
#   'pn player_url': 'https://www.whoscored.com/Players/136810',
#   'pn team_name': 'Valencia,',
#   'pn team_url': 'https://www.whoscored.com/Teams/55',
#   'rank': '50',
#   'rating': '7.12',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '1',
#   'ap': '6(1)',
#   'assistTotal': '-',
#   'goal': '3',
#   'manOfTheMatch': '-',
#   'minsPlayed': '482',
#   'passSuccess': '71',
#   'pn player_metadata': '25, AM(L)',
#   'pn player_name': 'Denis Cheryshev',
#   'pn player_url': 'https://www.whoscored.com/Players/110297',
#   'pn team_name': 'Valencia,',
#   'pn team_url': 'https://www.whoscored.com/Teams/55',
#   'rank': '51',
#   'rating': '7.12',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-ru',
#   'shotsPerGame': '1.9',
#   'yellowCard': '2'},
#  {'aerialWonPerGame': '0.8',
#   'ap': '7(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '707',
#   'passSuccess': '53.9',
#   'pn player_metadata': '25, GK',
#   'pn player_name': 'Raúl Lizoain',
#   'pn player_url': 'https://www.whoscored.com/Players/141028',
#   'pn team_name': 'Las Palmas,',
#   'pn team_url': 'https://www.whoscored.com/Teams/838',
#   'rank': '52',
#   'rating': '7.12',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '0.2',
#   'ap': '30(1)',
#   'assistTotal': '6',
#   'goal': '7',
#   'manOfTheMatch': '2',
#   'minsPlayed': '2535',
#   'passSuccess': '75',
#   'pn player_metadata': '24, M(CLR)',
#   'pn player_name': 'Pablo Sarabia',
#   'pn player_url': 'https://www.whoscored.com/Players/94868',
#   'pn team_name': 'Getafe,',
#   'pn team_url': 'https://www.whoscored.com/Teams/819',
#   'rank': '53',
#   'rating': '7.12',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '2',
#   'yellowCard': '9'},
#  {'aerialWonPerGame': '1.1',
#   'ap': '29(6)',
#   'assistTotal': '6',
#   'goal': '6',
#   'manOfTheMatch': '3',
#   'minsPlayed': '2497',
#   'passSuccess': '70.8',
#   'pn player_metadata': '25, M(CLR)',
#   'pn player_name': 'Rubén Rochina',
#   'pn player_url': 'https://www.whoscored.com/Players/91273',
#   'pn team_name': 'Granada,',
#   'pn team_url': 'https://www.whoscored.com/Teams/925',
#   'rank': '54',
#   'rating': '7.11',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '2.2',
#   'yellowCard': '10'},
#  {'aerialWonPerGame': '1.1',
#   'ap': '25(3)',
#   'assistTotal': '4',
#   'goal': '1',
#   'manOfTheMatch': '2',
#   'minsPlayed': '2121',
#   'passSuccess': '78.6',
#   'pn player_metadata': '22, D(R),M(R)',
#   'pn player_name': 'João Cancelo',
#   'pn player_url': 'https://www.whoscored.com/Players/128967',
#   'pn team_name': 'Valencia,',
#   'pn team_url': 'https://www.whoscored.com/Teams/55',
#   'rank': '55',
#   'rating': '7.10',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-pt',
#   'shotsPerGame': '0.3',
#   'yellowCard': '5'},
#  {'aerialWonPerGame': '0.1',
#   'ap': '35(1)',
#   'assistTotal': '8',
#   'goal': '17',
#   'manOfTheMatch': '2',
#   'minsPlayed': '3141',
#   'passSuccess': '79.1',
#   'pn player_metadata': '27, AM(CR),FW',
#   'pn player_name': 'Lucas Pérez',
#   'pn player_url': 'https://www.whoscored.com/Players/135663',
#   'pn team_name': 'Deportivo La Coruna,',
#   'pn team_url': 'https://www.whoscored.com/Teams/59',
#   'rank': '56',
#   'rating': '7.10',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '2.8',
#   'yellowCard': '3'},
#  {'aerialWonPerGame': '2',
#   'ap': '18(1)',
#   'assistTotal': '1',
#   'goal': '2',
#   'manOfTheMatch': '1',
#   'minsPlayed': '1609',
#   'passSuccess': '80.3',
#   'pn player_metadata': '34, D(R)',
#   'pn player_name': 'David García',
#   'pn player_url': 'https://www.whoscored.com/Players/79838',
#   'pn team_name': 'Las Palmas,',
#   'pn team_url': 'https://www.whoscored.com/Teams/838',
#   'rank': '57',
#   'rating': '7.10',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.5',
#   'yellowCard': '2'},
#  {'aerialWonPerGame': '0.1',
#   'ap': '13(3)',
#   'assistTotal': '1',
#   'goal': '1',
#   'manOfTheMatch': '-',
#   'minsPlayed': '1228',
#   'passSuccess': '78.4',
#   'pn player_metadata': '19, AM(LR)',
#   'pn player_name': 'Charly Musonda',
#   'pn player_url': 'https://www.whoscored.com/Players/303172',
#   'pn team_name': 'Real Betis,',
#   'pn team_url': 'https://www.whoscored.com/Teams/54',
#   'rank': '58',
#   'rating': '7.09',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-be',
#   'shotsPerGame': '0.9',
#   'yellowCard': '2'},
#  {'aerialWonPerGame': '0.6',
#   'ap': '34',
#   'assistTotal': '7',
#   'goal': '7',
#   'manOfTheMatch': '2',
#   'minsPlayed': '2921',
#   'passSuccess': '77.8',
#   'pn player_metadata': '30, AM(CLR)',
#   'pn player_name': 'Orellana',
#   'pn player_url': 'https://www.whoscored.com/Players/25714',
#   'pn team_name': 'Celta Vigo,',
#   'pn team_url': 'https://www.whoscored.com/Teams/62',
#   'rank': '59',
#   'rating': '7.09',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-cl',
#   'shotsPerGame': '2.3',
#   'yellowCard': '9'},
#  {'aerialWonPerGame': '4',
#   'ap': '16',
#   'assistTotal': '-',
#   'goal': '1',
#   'manOfTheMatch': '1',
#   'minsPlayed': '1338',
#   'passSuccess': '69.6',
#   'pn player_metadata': '27, D(C)',
#   'pn player_name': 'Bernardo',
#   'pn player_url': 'https://www.whoscored.com/Players/67327',
#   'pn team_name': 'Sporting Gijon,',
#   'pn team_url': 'https://www.whoscored.com/Teams/830',
#   'rank': '60',
#   'rating': '7.09',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-co',
#   'shotsPerGame': '0.8',
#   'yellowCard': '5'},
#  {'aerialWonPerGame': '-',
#   'ap': '1',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '90',
#   'passSuccess': '40.5',
#   'pn player_metadata': '28, GK',
#   'pn player_name': 'Jesús Fernández',
#   'pn player_url': 'https://www.whoscored.com/Players/75526',
#   'pn team_name': 'Granada,',
#   'pn team_url': 'https://www.whoscored.com/Teams/925',
#   'rank': '61',
#   'rating': '7.09',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '0.3',
#   'ap': '21(10)',
#   'assistTotal': '7',
#   'goal': '3',
#   'manOfTheMatch': '-',
#   'minsPlayed': '1826',
#   'passSuccess': '89.2',
#   'pn player_metadata': '24, AM(CLR),FW',
#   'pn player_name': 'Isco',
#   'pn player_url': 'https://www.whoscored.com/Players/82989',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '62',
#   'rating': '7.09',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '1.3',
#   'yellowCard': '2'},
#  {'aerialWonPerGame': '0.6',
#   'ap': '32',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '3',
#   'minsPlayed': '2880',
#   'passSuccess': '46.7',
#   'pn player_metadata': '23, GK',
#   'pn player_name': 'Alphonse Areola',
#   'pn player_url': 'https://www.whoscored.com/Players/92516',
#   'pn team_name': 'Villarreal,',
#   'pn team_url': 'https://www.whoscored.com/Teams/839',
#   'rank': '63',
#   'rating': '7.09',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-fr',
#   'shotsPerGame': '-',
#   'yellowCard': '1'},
#  {'aerialWonPerGame': '1',
#   'ap': '12(1)',
#   'assistTotal': '-',
#   'goal': '1',
#   'manOfTheMatch': '-',
#   'minsPlayed': '1010',
#   'passSuccess': '83',
#   'pn player_metadata': '25, D(C)',
#   'pn player_name': 'Mateo Musacchio',
#   'pn player_url': 'https://www.whoscored.com/Players/61014',
#   'pn team_name': 'Villarreal,',
#   'pn team_url': 'https://www.whoscored.com/Teams/839',
#   'rank': '64',
#   'rating': '7.08',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-ar',
#   'shotsPerGame': '0.2',
#   'yellowCard': '1'},
#  {'aerialWonPerGame': '1.5',
#   'ap': '23(3)',
#   'assistTotal': '1',
#   'goal': '-',
#   'manOfTheMatch': '3',
#   'minsPlayed': '1973',
#   'passSuccess': '75.9',
#   'pn player_metadata': '29, D(R)',
#   'pn player_name': 'Miguel Lopes',
#   'pn player_url': 'https://www.whoscored.com/Players/43977',
#   'pn team_name': 'Granada,',
#   'pn team_url': 'https://www.whoscored.com/Teams/925',
#   'rank': '65',
#   'rating': '7.08',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-pt',
#   'shotsPerGame': '0.4',
#   'yellowCard': '8'},
#  {'aerialWonPerGame': '3',
#   'ap': '23(2)',
#   'assistTotal': '1',
#   'goal': '3',
#   'manOfTheMatch': '4',
#   'minsPlayed': '2165',
#   'passSuccess': '73.1',
#   'pn player_metadata': '25, D(C)',
#   'pn player_name': 'Germán Pezzella',
#   'pn player_url': 'https://www.whoscored.com/Players/121456',
#   'pn team_name': 'Real Betis,',
#   'pn team_url': 'https://www.whoscored.com/Teams/54',
#   'rank': '66',
#   'rating': '7.07',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-ar',
#   'shotsPerGame': '0.7',
#   'yellowCard': '9'},
#  {'aerialWonPerGame': '1.3',
#   'ap': '25(2)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '2247',
#   'passSuccess': '82.2',
#   'pn player_metadata': '28, D(L)',
#   'pn player_name': 'Dani Castellano',
#   'pn player_url': 'https://www.whoscored.com/Players/41033',
#   'pn team_name': 'Las Palmas,',
#   'pn team_url': 'https://www.whoscored.com/Teams/838',
#   'rank': '67',
#   'rating': '7.07',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-',
#   'shotsPerGame': '0.3',
#   'yellowCard': '5'},
#  {'aerialWonPerGame': '0.5',
#   'ap': '34(1)',
#   'assistTotal': '1',
#   'goal': '1',
#   'manOfTheMatch': '1',
#   'minsPlayed': '3030',
#   'passSuccess': '77.1',
#   'pn player_metadata': '31, D(R)',
#   'pn player_name': 'Juanfran',
#   'pn player_url': 'https://www.whoscored.com/Players/10332',
#   'pn team_name': 'Atletico Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/63',
#   'rank': '68',
#   'rating': '7.06',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.2',
#   'yellowCard': '6'},
#  {'aerialWonPerGame': '1.8',
#   'ap': '14(2)',
#   'assistTotal': '-',
#   'goal': '13',
#   'manOfTheMatch': '3',
#   'minsPlayed': '1174',
#   'passSuccess': '66.2',
#   'pn player_metadata': '29, FW',
#   'pn player_name': 'Imanol Agirretxe',
#   'pn player_url': 'https://www.whoscored.com/Players/14203',
#   'pn team_name': 'Real Sociedad,',
#   'pn team_url': 'https://www.whoscored.com/Teams/68',
#   'rank': '69',
#   'rating': '7.06',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '2.9',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '2.2',
#   'ap': '32',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '2807',
#   'passSuccess': '77.6',
#   'pn player_metadata': '26, D(C)',
#   'pn player_name': 'Bruno',
#   'pn player_url': 'https://www.whoscored.com/Players/294192',
#   'pn team_name': 'Real Betis,',
#   'pn team_url': 'https://www.whoscored.com/Teams/54',
#   'rank': '70',
#   'rating': '7.06',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-',
#   'shotsPerGame': '0.5',
#   'yellowCard': '9'},
#  {'aerialWonPerGame': '2.5',
#   'ap': '31',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '2675',
#   'passSuccess': '87.4',
#   'pn player_metadata': '30, D(C)',
#   'pn player_name': 'Cabral',
#   'pn player_url': 'https://www.whoscored.com/Players/15544',
#   'pn team_name': 'Celta Vigo,',
#   'pn team_url': 'https://www.whoscored.com/Teams/62',
#   'rank': '71',
#   'rating': '7.06',
#   'redCard': '2',
#   'rgn': 'ui-icon country flg-ar',
#   'shotsPerGame': '0.2',
#   'yellowCard': '9'},
#  {'aerialWonPerGame': '-',
#   'ap': '6',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '1',
#   'minsPlayed': '540',
#   'passSuccess': '43.5',
#   'pn player_metadata': '31, GK',
#   'pn player_name': 'Alberto García',
#   'pn player_url': 'https://www.whoscored.com/Players/31685',
#   'pn team_name': 'Sporting Gijon,',
#   'pn team_url': 'https://www.whoscored.com/Teams/830',
#   'rank': '72',
#   'rating': '7.05',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '2.8',
#   'ap': '30(4)',
#   'assistTotal': '3',
#   'goal': '2',
#   'manOfTheMatch': '2',
#   'minsPlayed': '2691',
#   'passSuccess': '78.7',
#   'pn player_metadata': '27, D(C),DMC',
#   'pn player_name': 'San José',
#   'pn player_url': 'https://www.whoscored.com/Players/79051',
#   'pn team_name': 'Athletic Club,',
#   'pn team_url': 'https://www.whoscored.com/Teams/53',
#   'rank': '73',
#   'rating': '7.05',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.7',
#   'yellowCard': '6'},
#  {'aerialWonPerGame': '0.6',
#   'ap': '24(5)',
#   'assistTotal': '4',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '2149',
#   'passSuccess': '87.2',
#   'pn player_metadata': '33, D(R)',
#   'pn player_name': 'Dani Alves',
#   'pn player_url': 'https://www.whoscored.com/Players/5780',
#   'pn team_name': 'Barcelona,',
#   'pn team_url': 'https://www.whoscored.com/Teams/65',
#   'rank': '74',
#   'rating': '7.05',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-br',
#   'shotsPerGame': '0.6',
#   'yellowCard': '6'},
#  {'aerialWonPerGame': '0.5',
#   'ap': '29(2)',
#   'assistTotal': '6',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '2591',
#   'passSuccess': '87.2',
#   'pn player_metadata': '27, D(L)',
#   'pn player_name': 'Jordi Alba',
#   'pn player_url': 'https://www.whoscored.com/Players/44288',
#   'pn team_name': 'Barcelona,',
#   'pn team_url': 'https://www.whoscored.com/Teams/65',
#   'rank': '75',
#   'rating': '7.05',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.2',
#   'yellowCard': '2'},
#  {'aerialWonPerGame': '1.8',
#   'ap': '16',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '1421',
#   'passSuccess': '78.4',
#   'pn player_metadata': '23, D(R)',
#   'pn player_name': 'Cristiano Piccini',
#   'pn player_url': 'https://www.whoscored.com/Players/94831',
#   'pn team_name': 'Real Betis,',
#   'pn team_url': 'https://www.whoscored.com/Teams/54',
#   'rank': '76',
#   'rating': '7.04',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-it',
#   'shotsPerGame': '0.9',
#   'yellowCard': '4'},
#  {'aerialWonPerGame': '1.4',
#   'ap': '8(2)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '834',
#   'passSuccess': '70.2',
#   'pn player_metadata': '20, D(C)',
#   'pn player_name': 'Lucas Hernández',
#   'pn player_url': 'https://www.whoscored.com/Players/139186',
#   'pn team_name': 'Atletico Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/63',
#   'rank': '77',
#   'rating': '7.04',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-fr',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '1.7',
#   'ap': '13',
#   'assistTotal': '1',
#   'goal': '-',
#   'manOfTheMatch': '1',
#   'minsPlayed': '1167',
#   'passSuccess': '77.7',
#   'pn player_metadata': '25, D(LR)',
#   'pn player_name': 'Martín Montoya',
#   'pn player_url': 'https://www.whoscored.com/Players/91387',
#   'pn team_name': 'Real Betis,',
#   'pn team_url': 'https://www.whoscored.com/Teams/54',
#   'rank': '78',
#   'rating': '7.04',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.1',
#   'yellowCard': '4'},
#  {'aerialWonPerGame': '0.3',
#   'ap': '33(1)',
#   'assistTotal': '10',
#   'goal': '4',
#   'manOfTheMatch': '4',
#   'minsPlayed': '2833',
#   'passSuccess': '81',
#   'pn player_metadata': '20, AM(CLR)',
#   'pn player_name': 'Marco Asensio',
#   'pn player_url': 'https://www.whoscored.com/Players/137467',
#   'pn team_name': 'Espanyol,',
#   'pn team_url': 'https://www.whoscored.com/Teams/70',
#   'rank': '79',
#   'rating': '7.03',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '1.8',
#   'yellowCard': '3'},
#  {'aerialWonPerGame': '0.4',
#   'ap': '32(4)',
#   'assistTotal': '5',
#   'goal': '1',
#   'manOfTheMatch': '2',
#   'minsPlayed': '2900',
#   'passSuccess': '81.3',
#   'pn player_metadata': '29, M(C)',
#   'pn player_name': 'Beñat',
#   'pn player_url': 'https://www.whoscored.com/Players/22811',
#   'pn team_name': 'Athletic Club,',
#   'pn team_url': 'https://www.whoscored.com/Teams/53',
#   'rank': '80',
#   'rating': '7.03',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.8',
#   'yellowCard': '8'},
#  {'aerialWonPerGame': '2.9',
#   'ap': '20',
#   'assistTotal': '-',
#   'goal': '1',
#   'manOfTheMatch': '5',
#   'minsPlayed': '1633',
#   'passSuccess': '75.9',
#   'pn player_metadata': '33, D(CLR)',
#   'pn player_name': 'Heiko Westermann',
#   'pn player_url': 'https://www.whoscored.com/Players/5673',
#   'pn team_name': 'Real Betis,',
#   'pn team_url': 'https://www.whoscored.com/Teams/54',
#   'rank': '81',
#   'rating': '7.02',
#   'redCard': '2',
#   'rgn': 'ui-icon country flg-de',
#   'shotsPerGame': '0.8',
#   'yellowCard': '3'},
#  {'aerialWonPerGame': '0.6',
#   'ap': '31(4)',
#   'assistTotal': '4',
#   'goal': '14',
#   'manOfTheMatch': '6',
#   'minsPlayed': '2668',
#   'passSuccess': '77.5',
#   'pn player_metadata': '29, AM(CR),FW',
#   'pn player_name': 'Iago Aspas',
#   'pn player_url': 'https://www.whoscored.com/Players/91242',
#   'pn team_name': 'Celta Vigo,',
#   'pn team_url': 'https://www.whoscored.com/Teams/62',
#   'rank': '82',
#   'rating': '7.02',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '2.3',
#   'yellowCard': '8'},
#  {'aerialWonPerGame': '1.4',
#   'ap': '33(1)',
#   'assistTotal': '3',
#   'goal': '1',
#   'manOfTheMatch': '1',
#   'minsPlayed': '2886',
#   'passSuccess': '70.6',
#   'pn player_metadata': '27, D(LR),M(CR)',
#   'pn player_name': 'De Marcos',
#   'pn player_url': 'https://www.whoscored.com/Players/78500',
#   'pn team_name': 'Athletic Club,',
#   'pn team_url': 'https://www.whoscored.com/Teams/53',
#   'rank': '83',
#   'rating': '7.02',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.4',
#   'yellowCard': '6'},
#  {'aerialWonPerGame': '3.8',
#   'ap': '33(2)',
#   'assistTotal': '3',
#   'goal': '12',
#   'manOfTheMatch': '4',
#   'minsPlayed': '3007',
#   'passSuccess': '70.4',
#   'pn player_metadata': '32, FW',
#   'pn player_name': 'Charles',
#   'pn player_url': 'https://www.whoscored.com/Players/102157',
#   'pn team_name': 'Malaga,',
#   'pn team_url': 'https://www.whoscored.com/Teams/69',
#   'rank': '84',
#   'rating': '7.02',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-br',
#   'shotsPerGame': '2.4',
#   'yellowCard': '12'},
#  {'aerialWonPerGame': '2.3',
#   'ap': '26(1)',
#   'assistTotal': '2',
#   'goal': '2',
#   'manOfTheMatch': '1',
#   'minsPlayed': '2189',
#   'passSuccess': '75.3',
#   'pn player_metadata': '24, M(C)',
#   'pn player_name': 'Sergio Álvarez',
#   'pn player_url': 'https://www.whoscored.com/Players/86826',
#   'pn team_name': 'Sporting Gijon,',
#   'pn team_url': 'https://www.whoscored.com/Teams/830',
#   'rank': '85',
#   'rating': '7.01',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.2',
#   'yellowCard': '7'},
#  {'aerialWonPerGame': '0.5',
#   'ap': '35(1)',
#   'assistTotal': '7',
#   'goal': '3',
#   'manOfTheMatch': '5',
#   'minsPlayed': '3119',
#   'passSuccess': '87.3',
#   'pn player_metadata': '35, M(C)',
#   'pn player_name': 'Roberto Trashorras',
#   'pn player_url': 'https://www.whoscored.com/Players/25119',
#   'pn team_name': 'Rayo Vallecano,',
#   'pn team_url': 'https://www.whoscored.com/Teams/64',
#   'rank': '86',
#   'rating': '7.01',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.9',
#   'yellowCard': '10'},
#  {'aerialWonPerGame': '0.9',
#   'ap': '17(1)',
#   'assistTotal': '1',
#   'goal': '1',
#   'manOfTheMatch': '2',
#   'minsPlayed': '1538',
#   'passSuccess': '78.4',
#   'pn player_metadata': '28, D(L),M(L)',
#   'pn player_name': 'Jaume Costa',
#   'pn player_url': 'https://www.whoscored.com/Players/69965',
#   'pn team_name': 'Villarreal,',
#   'pn team_url': 'https://www.whoscored.com/Teams/839',
#   'rank': '87',
#   'rating': '7.01',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.2',
#   'yellowCard': '8'},
#  {'aerialWonPerGame': '1.2',
#   'ap': '31(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '2694',
#   'passSuccess': '90.5',
#   'pn player_metadata': '32, D(C),M(C)',
#   'pn player_name': 'Javier Mascherano',
#   'pn player_url': 'https://www.whoscored.com/Players/7415',
#   'pn team_name': 'Barcelona,',
#   'pn team_url': 'https://www.whoscored.com/Teams/65',
#   'rank': '88',
#   'rating': '7.01',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-ar',
#   'shotsPerGame': '0.1',
#   'yellowCard': '9'},
#  {'aerialWonPerGame': '1.7',
#   'ap': '32(2)',
#   'assistTotal': '1',
#   'goal': '3',
#   'manOfTheMatch': '3',
#   'minsPlayed': '2829',
#   'passSuccess': '73.3',
#   'pn player_metadata': '23, DMC',
#   'pn player_name': 'Gonzalo Escalante',
#   'pn player_url': 'https://www.whoscored.com/Players/127764',
#   'pn team_name': 'Eibar,',
#   'pn team_url': 'https://www.whoscored.com/Teams/824',
#   'rank': '89',
#   'rating': '7.00',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-ar',
#   'shotsPerGame': '0.7',
#   'yellowCard': '15'},
#  {'aerialWonPerGame': '1.8',
#   'ap': '34',
#   'assistTotal': '-',
#   'goal': '2',
#   'manOfTheMatch': '4',
#   'minsPlayed': '3010',
#   'passSuccess': '79.7',
#   'pn player_metadata': '26, D(C),M(C)',
#   'pn player_name': "Alfred N'Diaye",
#   'pn player_url': 'https://www.whoscored.com/Players/34123',
#   'pn team_name': 'Real Betis,',
#   'pn team_url': 'https://www.whoscored.com/Teams/54',
#   'rank': '90',
#   'rating': '7.00',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-fr',
#   'shotsPerGame': '0.7',
#   'yellowCard': '6'},
#  {'aerialWonPerGame': '1.1',
#   'ap': '33(1)',
#   'assistTotal': '4',
#   'goal': '1',
#   'manOfTheMatch': '1',
#   'minsPlayed': '2944',
#   'passSuccess': '78.5',
#   'pn player_metadata': '25, D(CR)',
#   'pn player_name': 'Hugo Mallo',
#   'pn player_url': 'https://www.whoscored.com/Players/79929',
#   'pn team_name': 'Celta Vigo,',
#   'pn team_url': 'https://www.whoscored.com/Teams/62',
#   'rank': '91',
#   'rating': '7.00',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.2',
#   'yellowCard': '9'},
#  {'aerialWonPerGame': '0.4',
#   'ap': '15(1)',
#   'assistTotal': '1',
#   'goal': '1',
#   'manOfTheMatch': '1',
#   'minsPlayed': '1247',
#   'passSuccess': '70',
#   'pn player_metadata': '31, AM(LR)',
#   'pn player_name': 'Gonzalo Castro',
#   'pn player_url': 'https://www.whoscored.com/Players/25945',
#   'pn team_name': 'Malaga,',
#   'pn team_url': 'https://www.whoscored.com/Teams/69',
#   'rank': '92',
#   'rating': '7.00',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-uy',
#   'shotsPerGame': '1.3',
#   'yellowCard': '1'},
#  {'aerialWonPerGame': '-',
#   'ap': '4',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '360',
#   'passSuccess': '60.8',
#   'pn player_metadata': '29, GK',
#   'pn player_name': 'Kiko Casilla',
#   'pn player_url': 'https://www.whoscored.com/Players/23154',
#   'pn team_name': 'Real Madrid,',
#   'pn team_url': 'https://www.whoscored.com/Teams/52',
#   'rank': '93',
#   'rating': '6.99',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '1.9',
#   'ap': '10(5)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '1084',
#   'passSuccess': '74.3',
#   'pn player_metadata': '22, D(C)',
# ...
#   'pn team_url': 'https://www.whoscored.com/Teams/53',
#   'rank': '516',
#   'rating': '6.09',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.2',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '0.6',
#   'ap': '2(12)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '330',
#   'passSuccess': '72.6',
#   'pn player_metadata': '22, Forward',
#   'pn player_name': 'Mamadou Sylla',
#   'pn player_url': 'https://www.whoscored.com/Players/294008',
#   'pn team_name': 'Espanyol,',
#   'pn team_url': 'https://www.whoscored.com/Teams/70',
#   'rank': '517',
#   'rating': '6.08',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.6',
#   'yellowCard': '3'},
#  {'aerialWonPerGame': '-',
#   'ap': '0(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '12',
#   'passSuccess': '50',
#   'pn player_metadata': '26, D(R),M(R)',
#   'pn player_name': 'Douglas',
#   'pn player_url': 'https://www.whoscored.com/Players/74533',
#   'pn team_name': 'Barcelona,',
#   'pn team_url': 'https://www.whoscored.com/Teams/65',
#   'rank': '518',
#   'rating': '6.08',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-br',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '-',
#   'ap': '0(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '6',
#   'passSuccess': '80',
#   'pn player_metadata': '19, Midfielder',
#   'pn player_name': 'Igor Zubeldia',
#   'pn player_url': 'https://www.whoscored.com/Players/315566',
#   'pn team_name': 'Real Sociedad,',
#   'pn team_url': 'https://www.whoscored.com/Teams/68',
#   'rank': '519',
#   'rating': '6.08',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '0.3',
#   'ap': '1(7)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '210',
#   'passSuccess': '76.8',
#   'pn player_metadata': '17, Midfielder',
#   'pn player_name': 'Joni Montiel',
#   'pn player_url': 'https://www.whoscored.com/Players/301483',
#   'pn team_name': 'Rayo Vallecano,',
#   'pn team_url': 'https://www.whoscored.com/Teams/64',
#   'rank': '520',
#   'rating': '6.08',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.3',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '-',
#   'ap': '1(2)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '83',
#   'passSuccess': '57.7',
#   'pn player_metadata': '29, Forward',
#   'pn player_name': 'Hugo Fraile',
#   'pn player_url': 'https://www.whoscored.com/Players/113884',
#   'pn team_name': 'Sporting Gijon,',
#   'pn team_url': 'https://www.whoscored.com/Teams/830',
#   'rank': '521',
#   'rating': '6.07',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '0.7',
#   'ap': '5(8)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '527',
#   'passSuccess': '70.7',
#   'pn player_metadata': '30, AM(R)',
#   'pn player_name': 'Jordi Xumetra',
#   'pn player_url': 'https://www.whoscored.com/Players/44282',
#   'pn team_name': 'Levante,',
#   'pn team_url': 'https://www.whoscored.com/Teams/832',
#   'rank': '522',
#   'rating': '6.06',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.6',
#   'yellowCard': '5'},
#  {'aerialWonPerGame': '-',
#   'ap': '1(2)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '81',
#   'passSuccess': '77.8',
#   'pn player_metadata': '32, FW',
#   'pn player_name': 'Ikechukwu Uche',
#   'pn player_url': 'https://www.whoscored.com/Players/14219',
#   'pn team_name': 'Malaga,',
#   'pn team_url': 'https://www.whoscored.com/Teams/69',
#   'rank': '523',
#   'rating': '6.06',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-ng',
#   'shotsPerGame': '0.3',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '-',
#   'ap': '2(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '227',
#   'passSuccess': '48.7',
#   'pn player_metadata': '26, GK',
#   'pn player_name': 'Oier',
#   'pn player_url': 'https://www.whoscored.com/Players/33960',
#   'pn team_name': 'Real Sociedad,',
#   'pn team_url': 'https://www.whoscored.com/Teams/68',
#   'rank': '524',
#   'rating': '6.05',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '1'},
#  {'aerialWonPerGame': '-',
#   'ap': '1(4)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '116',
#   'passSuccess': '74.4',
#   'pn player_metadata': '26, AM(L)',
#   'pn player_name': 'Ibai Gómez',
#   'pn player_url': 'https://www.whoscored.com/Players/91193',
#   'pn team_name': 'Athletic Club,',
#   'pn team_url': 'https://www.whoscored.com/Teams/53',
#   'rank': '525',
#   'rating': '6.05',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '0.4',
#   'yellowCard': '3'},
#  {'aerialWonPerGame': '-',
#   'ap': '0(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '4',
#   'passSuccess': '100',
#   'pn player_metadata': '24, Goalkeeper',
#   'pn player_name': 'Néstor',
#   'pn player_url': 'https://www.whoscored.com/Players/294190',
#   'pn team_name': 'Celta Vigo,',
#   'pn team_url': 'https://www.whoscored.com/Teams/62',
#   'rank': '526',
#   'rating': '6.04',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '-',
#   'ap': '0(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '3',
#   'passSuccess': '75',
#   'pn player_metadata': '18, Midfielder',
#   'pn player_name': 'Fran Villalba',
#   'pn player_url': 'https://www.whoscored.com/Players/300778',
#   'pn team_name': 'Valencia,',
#   'pn team_url': 'https://www.whoscored.com/Teams/55',
#   'rank': '527',
#   'rating': '6.03',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '1'},
#  {'aerialWonPerGame': '-',
#   'ap': '2',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '180',
#   'passSuccess': '52.7',
#   'pn player_metadata': '37, GK',
#   'pn player_name': 'Stipe Pletikosa',
#   'pn player_url': 'https://www.whoscored.com/Players/3300',
#   'pn team_name': 'Deportivo La Coruna,',
#   'pn team_url': 'https://www.whoscored.com/Teams/59',
#   'rank': '528',
#   'rating': '6.03',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-hr',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '-',
#   'ap': '0(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '5',
#   'passSuccess': '20',
#   'pn player_metadata': '23, Defender',
#   'pn player_name': 'Ander Gayoso',
#   'pn player_url': 'https://www.whoscored.com/Players/316831',
#   'pn team_name': 'Eibar,',
#   'pn team_url': 'https://www.whoscored.com/Teams/824',
#   'rank': '529',
#   'rating': '6.02',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '2.5',
#   'ap': '1(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '124',
#   'passSuccess': '57.6',
#   'pn player_metadata': '31, AM(L),FW',
#   'pn player_name': 'Henok Goitom',
#   'pn player_url': 'https://www.whoscored.com/Players/11352',
#   'pn team_name': 'Getafe,',
#   'pn team_url': 'https://www.whoscored.com/Teams/819',
#   'rank': '530',
#   'rating': '6.02',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-se',
#   'shotsPerGame': '2',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '-',
#   'ap': '1',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '90',
#   'passSuccess': '82.9',
#   'pn player_metadata': '21, Defender',
#   'pn player_name': 'Matos',
#   'pn player_url': 'https://www.whoscored.com/Players/316956',
#   'pn team_name': 'Sevilla,',
#   'pn team_url': 'https://www.whoscored.com/Teams/67',
#   'rank': '531',
#   'rating': '6.01',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '0.6',
#   'ap': '7(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '624',
#   'passSuccess': '60.5',
#   'pn player_metadata': '21, D(C)',
#   'pn player_name': 'Doria',
#   'pn player_url': 'https://www.whoscored.com/Players/129114',
#   'pn team_name': 'Granada,',
#   'pn team_url': 'https://www.whoscored.com/Teams/925',
#   'rank': '532',
#   'rating': '6.01',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-',
#   'shotsPerGame': '0.3',
#   'yellowCard': '3'},
#  {'aerialWonPerGame': '-',
#   'ap': '0(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '1',
#   'passSuccess': '-',
#   'pn player_metadata': '22, Defender',
#   'pn player_name': 'Imanol Corral',
#   'pn player_url': 'https://www.whoscored.com/Players/303440',
#   'pn team_name': 'Eibar,',
#   'pn team_url': 'https://www.whoscored.com/Teams/824',
#   'rank': '533',
#   'rating': '6.00',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '-',
#   'ap': '1',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '1',
#   'passSuccess': '-',
#   'pn player_metadata': '28, GK',
#   'pn player_name': 'Ivan Kelava',
#   'pn player_url': 'https://www.whoscored.com/Players/32710',
#   'pn team_name': 'Granada,',
#   'pn team_url': 'https://www.whoscored.com/Teams/925',
#   'rank': '534',
#   'rating': '6.00',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-hr',
#   'shotsPerGame': '-',
#   'yellowCard': '1'},
#  {'aerialWonPerGame': '-',
#   'ap': '0(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '1',
#   'passSuccess': '100',
#   'pn player_metadata': '24, M(C)',
#   'pn player_name': 'Lévy Madinda',
#   'pn player_url': 'https://www.whoscored.com/Players/108220',
#   'pn team_name': 'Celta Vigo,',
#   'pn team_url': 'https://www.whoscored.com/Teams/62',
#   'rank': '535',
#   'rating': '6.00',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-ga',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '2',
#   'ap': '3',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '270',
#   'passSuccess': '76.6',
#   'pn player_metadata': '27, D(L)',
#   'pn player_name': 'Lucas Orban',
#   'pn player_url': 'https://www.whoscored.com/Players/75204',
#   'pn team_name': 'Levante,',
#   'pn team_url': 'https://www.whoscored.com/Teams/832',
#   'rank': '536',
#   'rating': '5.99',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-ar',
#   'shotsPerGame': '-',
#   'yellowCard': '1'},
#  {'aerialWonPerGame': '1',
#   'ap': '0(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '27',
#   'passSuccess': '88.9',
#   'pn player_metadata': '20, Forward',
#   'pn player_name': 'Carlos Fernández',
#   'pn player_url': 'https://www.whoscored.com/Players/140812',
#   'pn team_name': 'Sevilla,',
#   'pn team_url': 'https://www.whoscored.com/Teams/67',
#   'rank': '537',
#   'rating': '5.99',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '-',
#   'ap': '0(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '2',
#   'passSuccess': '50',
#   'pn player_metadata': '21, Midfielder',
#   'pn player_name': 'Tropi',
#   'pn player_url': 'https://www.whoscored.com/Players/261670',
#   'pn team_name': 'Valencia,',
#   'pn team_url': 'https://www.whoscored.com/Teams/55',
#   'rank': '538',
#   'rating': '5.98',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '-',
#   'ap': '0(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '8',
#   'passSuccess': '100',
#   'pn player_metadata': '27, D(R)',
#   'pn player_name': 'Zhang Chengdong',
#   'pn player_url': 'https://www.whoscored.com/Players/63310',
#   'pn team_name': 'Rayo Vallecano,',
#   'pn team_url': 'https://www.whoscored.com/Teams/64',
#   'rank': '539',
#   'rating': '5.98',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '0.3',
#   'ap': '8(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '683',
#   'passSuccess': '42.1',
#   'pn player_metadata': '30, GK',
#   'pn player_name': 'Manu',
#   'pn player_url': 'https://www.whoscored.com/Players/34046',
#   'pn team_name': 'Deportivo La Coruna,',
#   'pn team_url': 'https://www.whoscored.com/Teams/59',
#   'rank': '540',
#   'rating': '5.98',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '2'},
#  {'aerialWonPerGame': '-',
#   'ap': '0(2)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '50',
#   'passSuccess': '80',
#   'pn player_metadata': '21, Defender',
#   'pn player_name': 'Rober',
#   'pn player_url': 'https://www.whoscored.com/Players/301467',
#   'pn team_name': 'Deportivo La Coruna,',
#   'pn team_url': 'https://www.whoscored.com/Teams/59',
#   'rank': '541',
#   'rating': '5.97',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-',
#   'shotsPerGame': '0.5',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '0.2',
#   'ap': '1(5)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '104',
#   'passSuccess': '83.3',
#   'pn player_metadata': '20, Midfielder',
#   'pn player_name': 'Dejan Drazic',
#   'pn player_url': 'https://www.whoscored.com/Players/137296',
#   'pn team_name': 'Celta Vigo,',
#   'pn team_url': 'https://www.whoscored.com/Teams/62',
#   'rank': '542',
#   'rating': '5.95',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-rs',
#   'shotsPerGame': '0.2',
#   'yellowCard': '1'},
#  {'aerialWonPerGame': '1',
#   'ap': '0(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '29',
#   'passSuccess': '57.1',
#   'pn player_metadata': '23, Forward',
#   'pn player_name': 'Mendi',
#   'pn player_url': 'https://www.whoscored.com/Players/140575',
#   'pn team_name': 'Sporting Gijon,',
#   'pn team_url': 'https://www.whoscored.com/Teams/830',
#   'rank': '543',
#   'rating': '5.94',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '1',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '-',
#   'ap': '1(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '174',
#   'passSuccess': '50',
#   'pn player_metadata': '28, GK',
#   'pn player_name': 'Iago Herrerín',
#   'pn player_url': 'https://www.whoscored.com/Players/101134',
#   'pn team_name': 'Athletic Club,',
#   'pn team_url': 'https://www.whoscored.com/Teams/53',
#   'rank': '544',
#   'rating': '5.80',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '2',
#   'ap': '2',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '136',
#   'passSuccess': '77.6',
#   'pn player_metadata': '32, D(C)',
#   'pn player_name': 'Michael Ciani',
#   'pn player_url': 'https://www.whoscored.com/Players/14241',
#   'pn team_name': 'Espanyol,',
#   'pn team_url': 'https://www.whoscored.com/Teams/70',
#   'rank': '545',
#   'rating': '5.70',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-fr',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '0.7',
#   'ap': '3',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '226',
#   'passSuccess': '33.9',
#   'pn player_metadata': '28, GK',
#   'pn player_name': 'Giedrius Arlauskis',
#   'pn player_url': 'https://www.whoscored.com/Players/66957',
#   'pn team_name': 'Espanyol,',
#   'pn team_url': 'https://www.whoscored.com/Teams/70',
#   'rank': '546',
#   'rating': '5.47',
#   'redCard': '-',
#   'rgn': 'ui-icon country flg-lt',
#   'shotsPerGame': '-',
#   'yellowCard': '-'},
#  {'aerialWonPerGame': '-',
#   'ap': '1(1)',
#   'assistTotal': '-',
#   'goal': '-',
#   'manOfTheMatch': '-',
#   'minsPlayed': '74',
#   'passSuccess': '87.5',
#   'pn player_metadata': '21, Defender',
#   'pn player_name': 'Salva Ruiz',
#   'pn player_url': 'https://www.whoscored.com/Players/142614',
#   'pn team_name': 'Granada,',
#   'pn team_url': 'https://www.whoscored.com/Teams/925',
#   'rank': '547',
#   'rating': '5.40',
#   'redCard': '1',
#   'rgn': 'ui-icon country flg-es',
#   'shotsPerGame': '-',
#   'yellowCard': '-'}]

# %%
# Save data to a file in json format
with open(os.path.join('data', 'players.json'), 'w') as f:
    f.write(json.dumps(rows, indent=2))
